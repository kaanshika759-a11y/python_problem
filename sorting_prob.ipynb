# %%
num=int(input("Enter the number of element:"))
arr=[]
for i in range(num):
    x=int(input("Enter the element:"))
    arr.append(x)
arr.sort()
print(arr)
# Out:
# Enter the element of number: 4
# Enter the element: 2
# Enter the element: 9
# Enter the element: 1
# Enter the element: 0
# [0, 1, 2, 9]

# %%
num=int(input("Enter the number of element:"))
arr=[]
for i in range(num):
    x=int(input("Enter the element:"))
    arr.append(x)
arr.sort(reverse=True)
print(arr)
# Out:
# Enter the element of number: 5
# Enter the element: 12
# Enter the element: 10
# Enter the element: 87
# Enter the element: 22
# Enter the element: 81
# [87, 81, 22, 12, 10]

# %%
a=int(input("Enter the number of element:"))
arr=[]
for i in range(a):
    x=int(input("Enter the element:"))
    arr.append(x)
result=sorted(arr)
print("result",result)
# Out:
# Enter the number of element: 3
# Enter the element: 1
# Enter the element: 0
# Enter the element: 3
# result [0, 1, 3]

# %%
n=int(input("Enter the element:"))
arr=[]
for i in range(n):
    x=int(input("Enter the element:"))
    arr.append(x)
result=sorted(arr)
print("arr=",arr)
print("Result=",result)
# Out:
# Enter the element: 5
# Enter the element: 12
# Enter the element: 1
# Enter the element: 2
# Enter the element: 10
# Enter the element: 20
# arr= [12, 1, 2, 10, 20]
# Result= [1, 2, 10, 12, 20]

# %%
arr=["aanshika","ansh","avinash","ayush"]
arr.sort()
print(arr)
# Out:
# ['aanshika', 'ansh', 'avinash', 'ayush']

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=str(input("Enter the string:"))
    arr.append(x)
arr.sort()
print(arr)
# Out:
# Enter the number of element: 5
# Enter the string: avinash
# Enter the string: ansh
# Enter the string: akash
# Enter the string: ayush
# Enter the string: saloni
# ['akash', 'ansh', 'avinash', 'ayush', 'saloni']

# %%
names=["aanshika","ansh","avinash","ayush"]
result=sorted(names)
print("result=",result)
# Out:
# result= ['aanshika', 'ansh', 'avinash', 'ayush']

# %%
a=int(input("Enter the element:"))
arr=[]
for i in range(a):
    x=str(input("Enter the string:"))
    arr.append(x)
result=sorted(arr)
print("result=",result)
# Out:
# Enter the element: 3
# Enter the string: aamamama
# Enter the string: malorj
# Enter the string: qwojf
# result= ['aamamama', 'malorj', 'qwojf']

# %%
students = [
    ("Rahul", 85),
    ("Amit", 92),
    ("Neha", 78),
    ("Raj", 90)
]
p=sorted(students,key=lambda x:x[1])
print(p)
# Out:
# [('Neha', 78), ('Rahul', 85), ('Raj', 90), ('Amit', 92)]

# %%
family=[
    ("aanshika" , 422),
    ("saloni",342),
    ("sonali",440),
    ("muskan",271),
    ("avinash",209)
]
result=sorted(family, key=lambda x:x[1])# here x is a parameter because lambda use anonmouys function..
print(result)
# Out:
# [('avinash', 209), ('muskan', 271), ('saloni', 342), ('aanshika', 422), ('sonali', 440)]

# %%
shoapkeeper=[
    ("Mohan",2330),
    ("mayur",11000),
    ("montu",40002),
    ("manav",100000)
]
accord_to_mon=sorted(shoapkeeper, key=lambda x:x[1])
print(accord_to_mon)
# Out:
# [('Mohan', 2330), ('mayur', 11000), ('montu', 40002), ('manav', 100000)]

# %%
employee=[
    ("aamayara",12000),
    ("anaya",30000),
    ("amins",5000)
]
res=sorted(employee,key=lambda s:s[1],  reverse=True)
print(res)
# Out:
# [('anaya', 30000), ('aamayara', 12000), ('amins', 5000)]

# %%
words=[
    "python",
    "java",
    "c",
    "javaScript",
    "go"
]
result=sorted(words, key=lambda x:len(x))
print("result=",result)
# Out:
# result= ['c', 'go', 'java', 'python', 'javaScript']

# %%
def square(x):
    return x*x
print(square(5))
# Out:
# 25

# %%
arr=[12,10,28,21,91]
result=sorted(arr)
print("arr=",arr)
print("Result=",result)
# Out:
# arr= [12, 10, 28, 21, 91]
# Result= [10, 12, 21, 28, 91]

# %%
arr=[100,10,101,1010,120,20,4002]
arr.sort()
print(arr)
# Out:
# [10, 20, 100, 101, 120, 1010, 4002]

# %%
student=[
    ("ansh",220),
    ("aanshika",781),
    ("avinash",661),
    ("anvi",112),
    ("ayush",888)
]
result=sorted(student,key=lambda x:(x[1],x[0]))
print(result)
# Out:
# [('anvi', 112), ('ansh', 220), ('avinash', 661), ('aanshika', 781), ('ayush', 888)]

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=int(input("Enter the element:"))
    arr.append(x)
arr.sort()
print(arr)
# Out:
# Enter the number of element: 5
# Enter the element: -1
# Enter the element: -100000000
# Enter the element: -21
# Enter the element: -34
# Enter the element: -200000000
# [-200000000, -100000000, -34, -21, -1]

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=int(input("Enter the element:"))
    arr.append(x)
result=set(arr)
result=sorted(result,reverse=True)
print(result)
# Out:
# Enter the number of element: 5
# Enter the element: 1
# Enter the element: 2
# Enter the element: 3
# Enter the element: 1
# Enter the element: 2
# [3, 2, 1]

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=int(input("Enter the element:"))
    arr.append(x)
result=set(arr)
result=sorted(result)
print(result)
# Out:
# Enter the number of element: 6
# Enter the element: 1
# Enter the element: 2
# Enter the element: 3
# Enter the element: 4
# Enter the element: 1
# Enter the element: 2
# [1, 2, 3, 4]

# %%
arr=[]
arr.sort()
print(arr)
# Out:
# []

# %%
t=(12,45,11,21,92)
result=tuple(sorted(t))
print(result)
# Out:
# (11, 12, 21, 45, 92)

# %%
n=int(input("Enter the number of element:"))
tup=[]
for i in range(n):
    x=int(input("Enter the element:"))
    tup.append(x)
result=tuple(sorted(tup))
print(result)
# Out:
# Enter the number of element: 9
# Enter the element: 1
# Enter the element: 2
# Enter the element: 3
# Enter the element: 4
# Enter the element: 5
# Enter the element: 1
# Enter the element: 8
# Enter the element: 2
# Enter the element: 7
# (1, 1, 2, 2, 3, 4, 5, 7, 8)

# %%
arr=['a','m','c','e','y','q']
arr.sort()
print(arr)
# Out:
# ['a', 'c', 'e', 'm', 'q', 'y']

# %%
arr=["aanshika","doll","bisvi","eva","curmiya","zuva"]
result=sorted(arr)
print(result)
# Out:
# ['aanshika', 'bisvi', 'curmiya', 'doll', 'eva', 'zuva']

# %%
arr=["aanshika","doll","bisvi","eva","curmiya","zuva"]
result=sorted(arr, reverse=True)
print(result)
# Out:
# ['zuva', 'eva', 'doll', 'curmiya', 'bisvi', 'aanshika']

# %%
arr=["aanshika","doll","bisvi","eva","curmiya","zuva"]
result=sorted(arr, reverse=True)
print(len(result))
# Out:
# 6

# %%
arr=["aanshika","doll","bisvi","eva","curmiya","zuva"]

result=sorted(arr , key=len)
print(result)
# Out:
# ['eva', 'doll', 'zuva', 'bisvi', 'curmiya', 'aanshika']

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=str(input("Enter the string:"))
    arr.append(x)
result=sorted(arr, key=len)
print(result)
# Out:
# Enter the number of element: 5
# Enter the string: eva
# Enter the string: eia
# Enter the string: anya
# Enter the string: anaya
# Enter the string: aarya
# ['eva', 'eia', 'anya', 'anaya', 'aarya']

# %%
n=int(input("Enter the number of element:"))
arr=[]
for i in range(n):
    x=str(input("Enter the string:"))
    arr.append(x)
result=sorted(arr, key=len, reverse=True)
print(result)
# Out:
# Enter the number of element: 5
# Enter the string: eva
# Enter the string: eia
# Enter the string: anya
# Enter the string: amayara
# Enter the string: anshi
# ['amayara', 'anshi', 'anya', 'eva', 'eia']

# %%
list1= [(3, "C"), (1, "A"), (2, "B")]
arr=[]
result=sorted(list1, key=lambda x:x[0])
print(result)
# Out:
# [(1, 'A'), (2, 'B'), (3, 'C')]

# %%
data = [(3, "C"), (1, "A"), (2, "B")]
arr=[]
result=sorted(data,key=lambda x:(x[1]))
print(result)
# Out:
# [(1, 'A'), (2, 'B'), (3, 'C')]

# %%
students = [
    ("Rahul", 85),
    ("Aman", 92),
    ("Riya", 78)
]
arr=[]
result=sorted(students, key=lambda x:x[1])
print(result)
# Out:
# [('Riya', 78), ('Rahul', 85), ('Aman', 92)]

# %%
students = [
    ("Rahul", 85),
    ("Aman", 92),
    ("Riya", 78)
]
arr=[]
result=sorted(students, key=lambda x:x[1], reverse=True)
print(result)
# Out:
# [('Aman', 92), ('Rahul', 85), ('Riya', 78)]

# %%
students = [
    ("Rahul", 85),
    ("Aman", 92),
    ("Riya", 78)
]
arr=[]
result=sorted(students, key=lambda x:x[0])
print(result)
# Out:
# [('Aman', 92), ('Rahul', 85), ('Riya', 78)]

# %%
words = ["banana", "Apple", "cherry", "apple"]
result=sorted(words)
print(result)
# Out:
# ['Apple', 'apple', 'banana', 'cherry']

# %%
students = [
    ("Rahul", 85),
    ("Aman", 92),
    ("Riya", 78)
]
result=sorted(students)
print(result)
# Out:
# [('Aman', 92), ('Rahul', 85), ('Riya', 78)]

# %%
nums = [-10, 3, -2, 7, -5]
result=sorted(nums, key=lambda x:abs(x))
print(result)
# Out:
# [-2, 3, -5, 7, -10]

# %%
marks = {
    "Rahul": 85,
    "Aman": 92,
    "Riya": 78,
    "Neha": 90
}
arr=[]
result=sorted(marks.items(), key=lambda x:(x[1]))
print(result)
# Out:
# [('Riya', 78), ('Rahul', 85), ('Neha', 90), ('Aman', 92)]

# %%
list1 = [0, 2, 1, 5, 3, 6, 11, 90, 25]

for i in range(len(list1)):
    for j in range(len(list1) - 1 - i):
        if list1[j] > list1[j + 1]:
            list1[j], list1[j + 1] = list1[j + 1], list1[j]

print(list1)
# Out:
# [0, 1, 2, 3, 5, 6, 11, 25, 90]

# %%
list1=[1,2,7,33,9,11,87]
arr=[]
for i in range(len(list1)):
    for j in range(len(list1)-1-i):
        if list1[j]>list1[j+1]:
            list1[j],list1[j+1]=list1[j+1],list1[j]
print(list1)
# Out:
# [87, 33, 11, 9, 7, 2, 1]

# %%
list1=[9,1,7,0,25,87]
arr=[]
for i in range(len(list1)):
    for j in range(len(list1)-1-i):
        if list1[j]<list1[j+1]:
            list1[j],list1[j+1]=list1[j+1],list1[j]
print(list1)
# Out:
# [87, 25, 9, 7, 1, 0]

# %%
list1=[87, 25, 9, 7, 1, 0]
smallest=list1[0]
for num in list1:
    if smallest>num:
        smallest=num
print(smallest)
# Out:
# 0

# %%
nums = [5, 2, 8, 1, 3]

largest = nums[0]
second_largest = nums[1]

for num in nums[2:]:
    if num > largest:
        second_largest = largest
        largest = num
    elif num > second_largest:
        second_largest = num

print(second_largest)
# Out:
# 5

# %%
nums=[5,2,8,1,3]
largest=nums[0]
second_largest=nums[1]
for num in nums:
    if num>largest:
        second_largest=largest
        largest=num
    elif num>second_largest:
        second_largest=num
print(second_largest)
# Out:
# 5

# %%
list1=[1,2,44,5,6,7,1,2,3,12,77]
result=set(list1)
print(result)
# Out:
# {1, 2, 3, 5, 6, 7, 44, 12, 77}

# %%
arr1=[2,1,3,4,5,6]
arr2=[2,1,3,599,3789]
result1=sorted(arr1)
result2=sorted(arr2)
print(result1+result2)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 599, 3789]

# %%
arr1=[2,1,3,4,5,6]
arr2=[2,1,3,599,3789]
arr3=[12,98,34,78,11]
result1=sorted(arr1)
result2=sorted(arr2)
result3=sorted(arr3)
print(result1+result2+result3)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 599, 3789, 11, 12, 34, 78, 98]

# %%
arr1=[2,1,3,4,5,6]
arr=[]
for i in range(len(arr1)):
    for j in range(len(arr1)-1-i):
       if arr1[j]>arr1[j+1]:
           arr1[j],arr1[j+1]=arr1[j+1],arr1[j]
print(arr1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr1=[2,1,3,4,5,6]
arr=[]
for i in range(len(arr1)):
    for j in range(len(arr1)-1-i):
       if arr1[j]<arr1[j+1]:
           arr1[j],arr1[j+1]=arr1[j+1],arr1[j]
print(arr1)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
nums = [5, 2, 8, 1, 3]

for i in range(len(nums)):
    swapped = False

    for j in range(len(nums) - 1 - i):

        if nums[j] > nums[j + 1]:
            nums[j], nums[j + 1] = nums[j + 1], nums[j]
            swapped = True

    if not swapped:
        break

print(nums)
# Out:
# [1, 2, 3, 5, 8]

# %%
nums = [5, 2, 8, 1, 3]
swap=0
for i in range(len(nums)):
    for j in range(len(nums)-1-i):
        if nums[j]<nums[j+1]:
            nums[j],nums[j+1]=nums[j+1],nums[j]
            swap+=1
print(swap)
print(nums)
# Out:
# 4
# [8, 5, 3, 2, 1]

# %%
arr=[9,8,6,1,2,3]

n=len(arr)
passes=0
for i in range(n-1):
    passes+=1
    for j in range(n-1-i):
        if arr[j]<arr[j+1]:
            arr[j],arr[j+1]=arr[j+1],arr[j]
print(passes)
# Out:
# 5

# %%
arr = [1, 2, 3, 4, 5]
sorted_list = True

for i in range(len(arr)):
    sorted_list = True   
    for j in range(len(arr) - 1 - i):
        if arr[j] > arr[j+1]:
            arr[j], arr[j+1] = arr[j+1], arr[j]
            sorted_list = False
            break   
    if not sorted_list:
        break   

if sorted_list:
    print("Sorted list")
else:
    print("Not sorted list")
# Out:
# Sorted list

# %%
arr=[2,1,5,3,4]
n=len(arr)
for i in range(n):
    min_index=i
    for j in range(i+1,n):
        if arr[j]<arr[min_index]:
            min_index=j
    arr[i],arr[min_index]=arr[min_index],arr[i]
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr=[2,11,55,12,34]
n=len(arr)
for i in range(n-1):
    min_index=i
    for j in range(i+1,n):
        if arr[j]>arr[min_index]:
            min_index=j
    arr[i],arr[min_index]=arr[min_index],arr[i]
print(arr)
# Out:
# [55, 34, 12, 11, 2]

# %%
arr=[1,2,3,2,4,1]
n=len(arr)
comparision=0
for i in range(n-1):
    min_index=i
    for j in range(i+1,n):
        comparision+=1
        if arr[j]<arr[min_index]:
            min_index=j
    arr[i],arr[min_index]=arr[min_index],arr[i]
print(arr)
print(comparision)
# Out:
# [1, 1, 2, 2, 3, 4]
# 15

# %%
arr=[1,2,3,2,4,1]
n=len(arr)
swap=0
for i in range(n-1):
    min_index=i
    for j in range(i+1, n):
        if arr[j]<arr[min_index]:
            min_index=j
    if min_index!=i:
        
        arr[i],arr[min_index]=arr[min_index],arr[i]
        swap=+1
    
    
print(swap)
print(arr)
# Out:
# 1
# [1, 1, 2, 2, 3, 4]

# %%
#insertion sort
arr = [5, 3, 4, 1, 2]

n = len(arr)

for i in range(1, n):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j = j - 1

    arr[j + 1] = key

print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr= [5, 3, 4, 1, 2]
n=len(arr)
for i in range(1,n):
    key=arr[i]
    j=i-1
    while j>=0 and arr[j]>key:
        arr[j+1]=arr[j]
        j=j-1
    arr[j+1]=key
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr=[5,3,1,2,4]
n=len(arr)
for i in range(1,n):
    key=arr[i]
    j=i-1
    while j>=0 and arr[j]>key:
        arr[j+1]=arr[j]
        j=j-1
    arr[j+1]=key
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr = [5, 3, 4, 1, 2]

n = len(arr)

for i in range(1, n):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] < key:
        arr[j + 1] = arr[j]
        j = j - 1

    arr[j + 1] = key

print(arr)
# Out:
# [5, 4, 3, 2, 1]

# %%
arr = [8, 3, 5, 1, 4, 2]

n = len(arr)

size = 1

while size < n:

    left = 0

    while left < n:

        mid = min(left + size, n)
        right = min(left + 2 * size, n)

        i = left
        j = mid

        temp = []

        while i < mid and j < right:

            if arr[i] <= arr[j]:
                temp.append(arr[i])
                i = i + 1
            else:
                temp.append(arr[j])
                j = j + 1

        while i < mid:
            temp.append(arr[i])
            i = i + 1

        while j < right:
            temp.append(arr[j])
            j = j + 1

        for k in range(len(temp)):
            arr[left + k] = temp[k]

        left = left + 2 * size

    size = size * 2

print(arr)
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
arr = [8, 3, 5, 1, 4, 2]

n = len(arr)

size = 1

while size < n:

    left = 0

    while left < n:

        mid = min(left + size, n)
        right = min(left + 2 * size, n)

        i = left
        j = mid

        temp = []

        while i < mid and j < right:

            if arr[i] <= arr[j]:
                temp.append(arr[i])
                i = i + 1
            else:
                temp.append(arr[j])
                j = j + 1

        while i < mid:
            temp.append(arr[i])
            i = i + 1

        while j < right:
            temp.append(arr[j])
            j = j + 1

        for k in range(len(temp)):
            arr[left + k] = temp[k]

        left = left + 2 * size

    size = size * 2

print(arr)
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
#recursive merge sort
def merge_sort(arr):
    # Base case
    if len(arr) <= 1:
        return arr

    # Divide
    mid = len(arr) // 2

    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    # Merge
    result = []
    i = 0
    j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    # Remaining elements
    result.extend(left[i:])
    result.extend(right[j:])

    return result


# Example
arr = [8, 3, 5, 2, 9, 1]

print("Original array:", arr)
print("Sorted array:", merge_sort(arr))
# Out:
# Original array: [8, 3, 5, 2, 9, 1]
# Sorted array: [1, 2, 3, 5, 8, 9]

# %%
def merge_and_count(left, right):
    result = []
    i = 0
    j = 0
    count = 0

    while i < len(left) and j < len(right):

        if left[i] <= right[j]:
            result.append(left[i])
            i += 1

        else:
            result.append(right[j])

            
            count += len(left) - i

            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result, count


def merge_sort_count(arr):

    if len(arr) <= 1:
        return arr, 0

    mid = len(arr) // 2

    left, left_count = merge_sort_count(arr[:mid])
    right, right_count = merge_sort_count(arr[mid:])

    merged, merge_count = merge_and_count(left, right)

    total_count = left_count + right_count + merge_count

    return merged, total_count



arr = [2, 4, 1, 3]

sorted_arr, inversions = merge_sort_count(arr)

print("Sorted array:", sorted_arr)
print("Inversion count:", inversions)
#inversion
# Out:
# Sorted array: [1, 2, 3, 4]
# Inversion count: 3
