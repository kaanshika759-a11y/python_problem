# %%
number=int(input("Enter the term:"))
a=0
b=1
for i in range(number):
    print(a, end=" ")
    c=a+b
    a=b
    b=c
# Out:
# Enter the term: 7
# 0 1 1 2 3 5 8

# %%
num=int(input("Enter the number:"))
a=0 
b=1
for i in range(num):
    print(a, end=" ")
    c=a+b
    a=b
    b=c
# Out:
# Enter the number: 5
# 0 1 1 2 3
