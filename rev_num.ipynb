# %%
num=int(input("Enter the number:"))
rev=0
while num>0:
    digit=num%10
    rev=rev*10+digit
    num//=10
print("Reversed number:",rev)
# Out:
# Enter the number: 1234
# Reversed number: 4321

# %%
num=int(input("Enter the number:"))
rev=0
while num>0:
    digit=num%10
    rev=rev*10+digit
    num//=10
print(rev)
# Out:
# Enter the number: 36767
# 76763
