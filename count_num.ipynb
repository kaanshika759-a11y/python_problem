# %%
num=int(input("Enter the number:"))
count=0
while num>0:
    count=count+1
    num=num//10
print(count)
# Out:
# Enter the number: 12234
# 5

# %%
num=int(input("Enter the number:"))
digit=len(str(num))
print(digit)
# Out:
# Enter the number: 3456789054321
# 13
